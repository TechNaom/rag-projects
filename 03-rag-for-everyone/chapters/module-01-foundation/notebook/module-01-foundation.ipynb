# %% [markdown]
# # Module 1: Foundation
#
# Understand why RAG exists, how a query moves through a RAG system, and how the major RAG families differ.
#
# ## Subtopics
# - Why LLMs hallucinate
# - Why context windows are limited
# - Why RAG exists
# - Different types of RAG
# - Naive RAG
# - Advanced RAG
# - Agentic RAG
# - Graph RAG
# - Corrective RAG
# - Adaptive RAG
# - Complete lifecycle of a query

# %%
topics = ['Why LLMs hallucinate', 'Why context windows are limited', 'Why RAG exists', 'Different types of RAG', 'Naive RAG', 'Advanced RAG', 'Agentic RAG', 'Graph RAG', 'Corrective RAG', 'Adaptive RAG', 'Complete lifecycle of a query']
print("Module 1: Foundation")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
