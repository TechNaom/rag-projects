# %% [markdown]
# # Module 4: Embeddings
#
# Explain vector similarity, compare embedding models, and reason about drift, dimensionality, and re-indexing.
#
# ## Subtopics
# - What embeddings are
# - Vector spaces
# - Similarity
# - Dimensionality
# - Distance metrics
# - Cosine similarity
# - Euclidean distance
# - Dot product
# - Embedding models
# - Domain-specific embeddings
# - Fine-tuning
# - Embedding drift
# - Re-indexing
# - Provider comparisons: OpenAI, Cohere, Google, and BAAI

# %%
topics = ['What embeddings are', 'Vector spaces', 'Similarity', 'Dimensionality', 'Distance metrics', 'Cosine similarity', 'Euclidean distance', 'Dot product', 'Embedding models', 'Domain-specific embeddings', 'Fine-tuning', 'Embedding drift', 'Re-indexing', 'Provider comparisons: OpenAI, Cohere, Google, and BAAI']
print("Module 4: Embeddings")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
