# %% [markdown]
# # Module 5: Vector Databases
#
# Understand ANN indexing, filtering, distributed design, and practical trade-offs across popular vector databases.
#
# ## Subtopics
# - ANN vs Exact Search
# - HNSW
# - IVF
# - PQ
# - OPQ
# - DiskANN
# - ScaNN
# - Filtering
# - Metadata search
# - Hybrid search
# - Distributed vector databases
# - Sharding
# - Replication
# - Database comparisons: Pinecone, Weaviate, Qdrant, Milvus, and Chroma

# %%
topics = ['ANN vs Exact Search', 'HNSW', 'IVF', 'PQ', 'OPQ', 'DiskANN', 'ScaNN', 'Filtering', 'Metadata search', 'Hybrid search', 'Distributed vector databases', 'Sharding', 'Replication', 'Database comparisons: Pinecone, Weaviate, Qdrant, Milvus, and Chroma']
print("Module 5: Vector Databases")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
