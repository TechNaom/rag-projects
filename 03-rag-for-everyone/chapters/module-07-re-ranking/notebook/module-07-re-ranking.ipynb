# %% [markdown]
# # Module 7: Re-ranking
#
# Explain why rerankers improve relevance and how to balance speed, cost, and accuracy.
#
# ## Subtopics
# - Cross-encoders
# - Bi-encoders
# - Late interaction
# - Why re-ranking improves quality
# - Trade-offs between speed and accuracy

# %%
topics = ['Cross-encoders', 'Bi-encoders', 'Late interaction', 'Why re-ranking improves quality', 'Trade-offs between speed and accuracy']
print("Module 7: Re-ranking")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
