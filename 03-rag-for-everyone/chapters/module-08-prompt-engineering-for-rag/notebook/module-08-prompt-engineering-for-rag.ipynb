# %% [markdown]
# # Module 8: Prompt Engineering for RAG
#
# Write grounded prompts that force citation behavior, structure outputs, and reduce hallucinations.
#
# ## Subtopics
# - Context injection
# - System prompts
# - Citation prompts
# - Grounding
# - Structured output
# - Guardrails
# - Hallucination prevention

# %%
topics = ['Context injection', 'System prompts', 'Citation prompts', 'Grounding', 'Structured output', 'Guardrails', 'Hallucination prevention']
print("Module 8: Prompt Engineering for RAG")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
