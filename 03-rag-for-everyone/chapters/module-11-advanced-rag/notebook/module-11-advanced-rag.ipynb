# %% [markdown]
# # Module 11: Advanced RAG
#
# Compare advanced RAG patterns and explain when added complexity is actually justified.
#
# ## Subtopics
# - Agentic RAG
# - Graph RAG
# - Knowledge Graph RAG
# - Multi-modal RAG
# - SQL RAG
# - Code RAG
# - Long-context RAG
# - Recursive retrieval
# - Adaptive retrieval
# - Multi-agent RAG

# %%
topics = ['Agentic RAG', 'Graph RAG', 'Knowledge Graph RAG', 'Multi-modal RAG', 'SQL RAG', 'Code RAG', 'Long-context RAG', 'Recursive retrieval', 'Adaptive retrieval', 'Multi-agent RAG']
print("Module 11: Advanced RAG")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
