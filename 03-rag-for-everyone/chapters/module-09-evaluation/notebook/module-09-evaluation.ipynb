# %% [markdown]
# # Module 9: Evaluation
#
# Measure retrieval quality, answer faithfulness, latency, and cost using practical metrics and frameworks.
#
# ## Subtopics
# - Recall@K
# - Precision@K
# - MRR
# - NDCG
# - Faithfulness
# - Context Precision
# - Answer Relevancy
# - Groundedness
# - Latency
# - Cost
# - Evaluation frameworks: Ragas and DeepEval

# %%
topics = ['Recall@K', 'Precision@K', 'MRR', 'NDCG', 'Faithfulness', 'Context Precision', 'Answer Relevancy', 'Groundedness', 'Latency', 'Cost', 'Evaluation frameworks: Ragas and DeepEval']
print("Module 9: Evaluation")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
