# %% [markdown]
# # Module 10: Production RAG
#
# Reason about reliability, observability, security, and cost control in a real production deployment.
#
# ## Subtopics
# - Caching
# - Streaming
# - Observability
# - Logging
# - Versioning
# - Security
# - Authentication
# - Rate limiting
# - Cost optimization
# - Monitoring
# - CI/CD
# - Failure handling

# %%
topics = ['Caching', 'Streaming', 'Observability', 'Logging', 'Versioning', 'Security', 'Authentication', 'Rate limiting', 'Cost optimization', 'Monitoring', 'CI/CD', 'Failure handling']
print("Module 10: Production RAG")
for index, topic in enumerate(topics, start=1):
    print(f"{index}. {topic}")
